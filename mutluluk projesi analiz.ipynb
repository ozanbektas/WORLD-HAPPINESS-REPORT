# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
import seaborn as sns



import plotly.offline as py
from plotly.offline import init_notebook_mode, iplot
import plotly.graph_objs as go

# %%
df = pd.read_csv("C:/Users/ozann/OneDrive/Masaüstü/dünya mutluluk raporu/2018.csv", low_memory=False)

# %%
df.head(10)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
# 5             6       Netherlands  7.441           1.361           1.488
# 6             7            Canada  7.328           1.330           1.532
# 7             8       New Zealand  7.324           1.268           1.601
# 8             9            Sweden  7.314           1.355           1.501
# 9            10         Australia  7.272           1.340           1.573
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# ...

# %%
df.columns=df.columns.str.replace(' ','_')

# %%
df.columns
# Out:
# Index(['Overall_rank', 'Country_or_region', 'Score', 'GDP_per_capita',
#        'Social_support', 'Healthy_life_expectancy',
#        'Freedom_to_make_life_choices', 'Generosity',
#        'Perceptions_of_corruption'],
#       dtype='object')

# %%
df.shape
# Out:
# (156, 9)

# %%
df.dtypes
# Out:
# Overall_rank                      int64
# Country_or_region                object
# Score                           float64
# GDP_per_capita                  float64
# Social_support                  float64
# Healthy_life_expectancy         float64
# Freedom_to_make_life_choices    float64
# Generosity                      float64
# Perceptions_of_corruption       float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Overall_rank', 'Country_or_region', 'Score', 'GDP_per_capita',
#        'Social_support', 'Healthy_life_expectancy',
#        'Freedom_to_make_life_choices', 'Generosity',
#        'Perceptions_of_corruption'],
#       dtype='object')

# %%
plt.rcParams['figure.figsize'] = (20, 15)
sns.heatmap(df.corr(), cmap = 'jet', annot = True)

plt.show()

# %%
sns.barplot(y = df["Country_or_region"][:10], x = df["GDP_per_capita"][:10])
# Out:
# <AxesSubplot: xlabel='GDP_per_capita', ylabel='Country_or_region'>

# %%
sns.barplot(y = df["Country_or_region"][:10], x = df["Social_support"][:10])
# Out:
# <AxesSubplot: xlabel='Social_support', ylabel='Country_or_region'>

# %%
sns.barplot(y = df["Country_or_region"][:10], x = df["Healthy_life_expectancy"][:10])
# Out:
# <AxesSubplot: xlabel='Healthy_life_expectancy', ylabel='Country_or_region'>

# %%
sns.barplot(y = df["Country_or_region"][:10], x = df["GDP_per_capita"][:-10])
# Out:
# <AxesSubplot: xlabel='GDP_per_capita', ylabel='Country_or_region'>

# %%
sns.barplot(y = df["Country_or_region"][-10:], x = df["Social_support"][-10:])
# Out:
# <AxesSubplot: xlabel='Social_support', ylabel='Country_or_region'>

# %%
sns.barplot(y = df["Country_or_region"][-10:], x = df["Healthy_life_expectancy"][-10:])
# Out:
# <AxesSubplot: xlabel='Healthy_life_expectancy', ylabel='Country_or_region'>

# %%
sns.barplot(y = df["Country_or_region"][70:80], x = df["Score"][70:80])
# Out:
# <AxesSubplot: xlabel='Score', ylabel='Country_or_region'>

# %%
df.columns
# Out:
# Index(['Overall_rank', 'Country_or_region', 'Score', 'GDP_per_capita',
#        'Social_support', 'Healthy_life_expectancy',
#        'Freedom_to_make_life_choices', 'Generosity',
#        'Perceptions_of_corruption'],
#       dtype='object')

# %%
f, axs = plt.subplots(3,2, figsize = (14,14), constrained_layout = True)

sort_fa = df.sort_values(by = ['Overall_rank'], ascending = False)
sort_fa = sort_fa.head(10)
sort_fa = df.sort_values(by = ['Social_support'], ascending = False)
sort_fa = sort_fa.head(10)
sort_he = df.sort_values(by = ['Healthy_life_expectancy'], ascending = False)
sort_he = sort_he.head(10)
sort_free = df.sort_values(by = ['Freedom_to_make_life_choices'], ascending = False)
sort_free = sort_free.head(10)
sort_gc = df.sort_values(by = ['Perceptions_of_corruption'], ascending = False)
sort_gc = sort_gc.head(10)
sort_genero = df.sort_values(by = ['GDP_per_capita'], ascending = False)
sort_genero = sort_genero.head(10)

ax=sns.barplot(x="Country_or_region",y="Overall_rank", data=sort_fa, ax = axs[0, 1])
ax.tick_params(axis = 'x', rotation = 90)
ax=sns.barplot(x="Country_or_region",y="Social_support", data=sort_fa, ax = axs[0, 1])
ax.tick_params(axis = 'x', rotation = 90)
ax=sns.barplot(x="Country_or_region",y="Healthy_life_expectancy", data=sort_he, ax = axs[1, 0])
ax.tick_params(axis = 'x', rotation = 90)
ax=sns.barplot(x="Country_or_region",y="Freedom_to_make_life_choices", data=sort_free, ax = axs[1, 1])
ax.tick_params(axis = 'x', rotation = 90)
ax=sns.barplot(x="Country_or_region",y="Perceptions_of_corruption", data = sort_gc, ax = axs[2, 0])
ax.tick_params(axis = 'x', rotation = 90)
ax=sns.barplot(x="Country_or_region",y="GDP_per_capita", data=sort_genero, ax = axs[2, 1])
ax.tick_params(axis = 'x', rotation = 90)

# %%
df.head()
# Out:
#    Overall_rank Country_or_region  Score  GDP_per_capita  Social_support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
#
#    Healthy_life_expectancy  Freedom_to_make_life_choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
# 4                    0.927                         0.660       0.256
#
#    Perceptions_of_corruption
# 0                      0.393
# 1                      0.340
# ...

# %%
df1=pd.read_csv('C:/Users/ozann/OneDrive/Masaüstü/dünya mutluluk raporu/2015.csv')
df2=pd.read_csv('C:/Users/ozann/OneDrive/Masaüstü/dünya mutluluk raporu/2016.csv')
df3=pd.read_csv('C:/Users/ozann/OneDrive/Masaüstü/dünya mutluluk raporu/2017.csv')
df4=pd.read_csv('C:/Users/ozann/OneDrive/Masaüstü/dünya mutluluk raporu/2019.csv')

# %%
df1.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df1.columns=df1.columns.str.replace(' ','_')

# %%
df1=df1.rename(columns={"Economy_(GDP_per_Capita)":"Economy","Health_(Life_Expectancy)":"Life_Expectancy",
                      "Trust_(Government_Corruption)":"Government_Corruption","Happiness_Rank":"Rank"
                      })

# %%
df1.columns
# Out:
# Index(['Country', 'Region', 'Rank', 'Happiness_Score', 'Standard_Error',
#        'Economy', 'Family', 'Life_Expectancy', 'Freedom',
#        'Government_Corruption', 'Generosity', 'Dystopia_Residual'],
#       dtype='object')

# %%
df2.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
df2.columns=df2.columns.str.replace('.','_')

# %%
df2.columns=df2.columns.str.replace('__','_')

# %%
df2.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Lower Confidence Interval', 'Upper Confidence Interval',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')

# %%
df2=df2.rename(columns={"Economy_GDP_per_Capita_":"Economy","Health_Life_Expectancy_":"Life_Expectancy",
                      "Trust_Government_Corruption_":"Government_Corruption","Happiness_Rank":"Rank"
                      })

# %%
df2.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Lower Confidence Interval', 'Upper Confidence Interval',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')

# %%
df3.columns
# Out:
# Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual'],
#       dtype='object')

# %%
df3.columns=df3.columns.str.replace(' ','_')

# %%
df3.columns
# Out:
# Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual'],
#       dtype='object')

# %%
df3.head(10)
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
# 5  Netherlands               6            7.377      7.427426     7.326574
# 6       Canada               7            7.316      7.384403     7.247597
# 7  New Zealand               8            7.314      7.379510     7.248490
# 8       Sweden               9            7.284      7.344095     7.223905
# 9    Australia              10            7.284      7.356651     7.211349
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# ...

# %%
df3=df3.rename(columns={"Country_or_region":"Country","GDP_per_capita":"Economy",
                        "Healthy_life_expectancy":"Life_Expectancy",
                      "Score":"Happiness_Score","Overall_rank":"Rank"
                      })

# %%
df3.columns
# Out:
# Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual'],
#       dtype='object')

# %%
df4.head(10)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
# 5             6       Switzerland  7.480           1.452           1.526
# 6             7            Sweden  7.343           1.387           1.487
# 7             8       New Zealand  7.307           1.303           1.557
# 8             9            Canada  7.278           1.365           1.505
# 9            10           Austria  7.246           1.376           1.475
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# ...

# %%
df4.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
df4.columns=df4.columns.str.replace(' ','_')

# %%
df4.columns
# Out:
# Index(['Overall_rank', 'Country_or_region', 'Score', 'GDP_per_capita',
#        'Social_support', 'Healthy_life_expectancy',
#        'Freedom_to_make_life_choices', 'Generosity',
#        'Perceptions_of_corruption'],
#       dtype='object')

# %%
df4=df4.rename(columns={"Country_or_region":"Country","GDP_per_capita":"Economy",
                        "Healthy_life_expectancy":"Life_Expectancy",
                      "Score":"Happiness_Score","Overall_rank":"Rank"
                      })

# %%
df4.head(10)
# Out:
#    Rank      Country  Happiness_Score  Economy  Social_support  \
# 0     1      Finland            7.769    1.340           1.587
# 1     2      Denmark            7.600    1.383           1.573
# 2     3       Norway            7.554    1.488           1.582
# 3     4      Iceland            7.494    1.380           1.624
# 4     5  Netherlands            7.488    1.396           1.522
# 5     6  Switzerland            7.480    1.452           1.526
# 6     7       Sweden            7.343    1.387           1.487
# 7     8  New Zealand            7.307    1.303           1.557
# 8     9       Canada            7.278    1.365           1.505
# 9    10      Austria            7.246    1.376           1.475
#
#    Life_Expectancy  Freedom_to_make_life_choices  Generosity  \
# 0            0.986                         0.596       0.153
# 1            0.996                         0.592       0.252
# 2            1.028                         0.603       0.271
# ...

# %%
df1=pd.read_csv('C:/Users/ozann/OneDrive/Masaüstü/dünya mutluluk raporu/2016.csv')
df2=pd.read_csv('C:/Users/ozann/OneDrive/Masaüstü/dünya mutluluk raporu/2017.csv')
df3=pd.read_csv('C:/Users/ozann/OneDrive/Masaüstü/dünya mutluluk raporu/2015.csv')
df4=pd.read_csv('C:/Users/ozann/OneDrive/Masaüstü/dünya mutluluk raporu/2019.csv')

# %%
df1.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Lower Confidence Interval', 'Upper Confidence Interval',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')

# %%
df1.columns=df1.columns.str.replace(' ','_')

# %%
df1=df1.rename(columns={"Economy_(GDP_per_Capita)":"Economy","Health_(Life_Expectancy)":"Life_Expectancy",
                      "Trust_(Government_Corruption)":"Government_Corruption","Happiness_Rank":"Rank"
                      })

# %%
df1.columns
# Out:
# Index(['Country', 'Region', 'Rank', 'Happiness_Score',
#        'Lower_Confidence_Interval', 'Upper_Confidence_Interval', 'Economy',
#        'Family', 'Life_Expectancy', 'Freedom', 'Government_Corruption',
#        'Generosity', 'Dystopia_Residual'],
#       dtype='object')

# %%
df2.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# ...

# %%
df2.columns=df2.columns.str.replace('.','_')

# %%
df2.columns
# Out:
# Index(['Country', 'Happiness_Rank', 'Happiness_Score', 'Whisker_high',
#        'Whisker_low', 'Economy__GDP_per_Capita_', 'Family',
#        'Health__Life_Expectancy_', 'Freedom', 'Generosity',
#        'Trust__Government_Corruption_', 'Dystopia_Residual'],
#       dtype='object')

# %%
df2=df2.rename(columns={"Economy_GDP_per_Capita_":"Economy","Health_Life_Expectancy_":"Life_Expectancy",
                      "Trust_Government_Corruption_":"Government_Corruption","Happiness_Rank":"Rank"
                      })

# %%
df2.columns
# Out:
# Index(['Country', 'Rank', 'Happiness_Score', 'Whisker_high', 'Whisker_low',
#        'Economy__GDP_per_Capita_', 'Family', 'Health__Life_Expectancy_',
#        'Freedom', 'Generosity', 'Trust__Government_Corruption_',
#        'Dystopia_Residual'],
#       dtype='object')

# %%
df3.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df3.columns=df3.columns.str.replace(' ','_')

# %%
df3.columns
# Out:
# Index(['Country', 'Region', 'Happiness_Rank', 'Happiness_Score',
#        'Standard_Error', 'Economy_(GDP_per_Capita)', 'Family',
#        'Health_(Life_Expectancy)', 'Freedom', 'Trust_(Government_Corruption)',
#        'Generosity', 'Dystopia_Residual'],
#       dtype='object')

# %%
df3.head(10)
# Out:
#        Country                     Region  Happiness_Rank  Happiness_Score  \
# 0  Switzerland             Western Europe               1            7.587
# 1      Iceland             Western Europe               2            7.561
# 2      Denmark             Western Europe               3            7.527
# 3       Norway             Western Europe               4            7.522
# 4       Canada              North America               5            7.427
# 5      Finland             Western Europe               6            7.406
# 6  Netherlands             Western Europe               7            7.378
# 7       Sweden             Western Europe               8            7.364
# 8  New Zealand  Australia and New Zealand               9            7.286
# 9    Australia  Australia and New Zealand              10            7.284
#
#    Standard_Error  Economy_(GDP_per_Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# ...

# %%
df3=df3.rename(columns={"Country_or_region":"Country","GDP_per_capita":"Economy",
                        "Healthy_life_expectancy":"Life_Expectancy",
                      "Score":"Happiness_Score","Overall_rank":"Rank"
                      })

# %%
df3.columns
# Out:
# Index(['Country', 'Region', 'Happiness_Rank', 'Happiness_Score',
#        'Standard_Error', 'Economy_(GDP_per_Capita)', 'Family',
#        'Health_(Life_Expectancy)', 'Freedom', 'Trust_(Government_Corruption)',
#        'Generosity', 'Dystopia_Residual'],
#       dtype='object')

# %%
df4.head(10)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
# 5             6       Switzerland  7.480           1.452           1.526
# 6             7            Sweden  7.343           1.387           1.487
# 7             8       New Zealand  7.307           1.303           1.557
# 8             9            Canada  7.278           1.365           1.505
# 9            10           Austria  7.246           1.376           1.475
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# ...

# %%
df4.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
df4.columns=df4.columns.str.replace(' ','_')

# %%
df4.columns
# Out:
# Index(['Overall_rank', 'Country_or_region', 'Score', 'GDP_per_capita',
#        'Social_support', 'Healthy_life_expectancy',
#        'Freedom_to_make_life_choices', 'Generosity',
#        'Perceptions_of_corruption'],
#       dtype='object')

# %%
df4=df4.rename(columns={"Country_or_region":"Country","GDP_per_capita":"Economy",
                        "Healthy_life_expectancy":"Life_Expectancy",
                      "Score":"Happiness_Score","Overall_rank":"Rank"
                      })

# %%
df4.head(10)
# Out:
#    Rank      Country  Happiness_Score  Economy  Social_support  \
# 0     1      Finland            7.769    1.340           1.587
# 1     2      Denmark            7.600    1.383           1.573
# 2     3       Norway            7.554    1.488           1.582
# 3     4      Iceland            7.494    1.380           1.624
# 4     5  Netherlands            7.488    1.396           1.522
# 5     6  Switzerland            7.480    1.452           1.526
# 6     7       Sweden            7.343    1.387           1.487
# 7     8  New Zealand            7.307    1.303           1.557
# 8     9       Canada            7.278    1.365           1.505
# 9    10      Austria            7.246    1.376           1.475
#
#    Life_Expectancy  Freedom_to_make_life_choices  Generosity  \
# 0            0.986                         0.596       0.153
# 1            0.996                         0.592       0.252
# 2            1.028                         0.603       0.271
# ...

# %%
sort_df1 = df1.head(10)
sort_df2 = df2.head(10)
sort_df3 = df3.head(10)
sort_df4 = df4.head(10)
sort_df = df.head(10)
sad_df4 = df4.tail(2)
f, axs = plt.subplots(3,2, figsize = (14,14), constrained_layout = True)
ax=sns.barplot(x="Country", y="Happiness_Score", data=sort_df3 , ax = axs[0, 0])
ax.tick_params(axis = 'x', rotation = 45)
ax=sns.barplot(x="Country",y="Happiness_Score", data=sort_df1, ax = axs[0, 1])
ax.tick_params(axis = 'x', rotation = 45)
ax=sns.barplot(x="Country",y="Happiness_Score", data=sort_df2, ax = axs[1, 0])
ax.tick_params(axis = 'x', rotation = 45)
ax=sns.barplot(x="Country",y="Happiness_Score", data=sort_df3, ax = axs[1, 1])
ax.tick_params(axis = 'x', rotation = 45)
ax=sns.barplot(x="Country",y="Happiness_Score", data =sort_df4, ax = axs[2, 0])
ax.tick_params(axis = 'x', rotation = 45)
ax=sns.barplot(x="Country",y="Happiness_Score", data =sad_df4, ax = axs[2, 1])
ax.tick_params(axis = 'x', rotation = 45)
axs[0, 0].title.set_text('2015  EN MUTLU 10 ULKE')
axs[0, 1].title.set_text('2016  EN MUTLU 10 ULKE')
axs[1, 0].title.set_text('2017  EN MUTLU 10 ULKE')
axs[1, 1].title.set_text('2018  EN MUTLU 10 ULKE')
axs[2, 0].title.set_text('2019  EN MUTLU 10 ULKE')
axs[2, 1].title.set_text('2019  EN MUTSUZ 2 ULKE')

# %%
sort_df1 = df1.tail(10)
sort_df2 = df2.tail(10)
sort_df3 = df3.tail(10)
sort_df4 = df4.tail(10)
sort_df = df.tail(10)
sad_df4 = df4.head(2)
f, axs = plt.subplots(3,2, figsize = (14,14), constrained_layout = True)
ax=sns.barplot(x="Country", y="Happiness_Score", data=sort_df3 , ax = axs[0, 0])
ax.tick_params(axis = 'x', rotation = 45)
ax=sns.barplot(x="Country",y="Happiness_Score", data=sort_df1, ax = axs[0, 1])
ax.tick_params(axis = 'x', rotation = 45)
ax=sns.barplot(x="Country",y="Happiness_Score", data=sort_df2, ax = axs[1, 0])
ax.tick_params(axis = 'x', rotation = 45)
ax=sns.barplot(x="Country",y="Happiness_Score", data=sort_df3, ax = axs[1, 1])
ax.tick_params(axis = 'x', rotation = 45)
ax=sns.barplot(x="Country",y="Happiness_Score", data =sort_df4, ax = axs[2, 0])
ax.tick_params(axis = 'x', rotation = 45)
ax=sns.barplot(x="Country",y="Happiness_Score", data =sad_df4, ax = axs[2, 1])
ax.tick_params(axis = 'x', rotation = 45)
axs[0, 0].title.set_text('2015 EN MUTSUZ 10 ULKE')
axs[0, 1].title.set_text('2016 EN MUTSUZ 10 ULKE')
axs[1, 0].title.set_text('2017 EN MUTSUZ 10 ULKE')
axs[1, 1].title.set_text('2018 EN MUTSUZ 10 ULKE')
axs[2, 0].title.set_text('2019 EN MUTSUZ 10 ULKE')
axs[2, 1].title.set_text('2019 EN MUTLU 2 ULKE')

# %%
unified=pd.read_csv('C:/Users/ozann/OneDrive/Masaüstü/dünya mutluluk raporu/toplu veri.csv')

# %%
unified.head(10)
# Out:
#        country   2015   2016   2017   2018   2019
# 0      Finland  7.406  7.413  7.469  7.632  7.769
# 1      Denmark  7.527  7.526  7.522  7.555  7.600
# 2       Norway  7.522  7.498  7.537  7.594  7.554
# 3      Iceland  7.561  7.501  7.504  7.495  7.494
# 4  Netherlands  7.378  7.339  7.377  7.441  7.488
# 5  Switzerland  7.587  7.509  7.494  7.487  7.480
# 6       Sweden  7.364  7.291  7.284  7.314  7.343
# 7  New Zealand  7.286  7.334  7.314  7.324  7.307
# 8       Canada  7.427  7.404  7.316  7.328  7.278
# 9      Austria  7.200  7.119  7.006  7.139  7.246

# %%
unified.head(10)
# Out:
#        country   2015   2016   2017   2018   2019
# 0      Finland  7.406  7.413  7.469  7.632  7.769
# 1      Denmark  7.527  7.526  7.522  7.555  7.600
# 2       Norway  7.522  7.498  7.537  7.594  7.554
# 3      Iceland  7.561  7.501  7.504  7.495  7.494
# 4  Netherlands  7.378  7.339  7.377  7.441  7.488
# 5  Switzerland  7.587  7.509  7.494  7.487  7.480
# 6       Sweden  7.364  7.291  7.284  7.314  7.343
# 7  New Zealand  7.286  7.334  7.314  7.324  7.307
# 8       Canada  7.427  7.404  7.316  7.328  7.278
# 9      Austria  7.200  7.119  7.006  7.139  7.246

# %%
a=unified['2019']-unified['2015'].round(3)

# %%
unified['difference']=a

# %%
unified.head(20)
# Out:
#          country   2015   2016   2017   2018   2019  difference
# 101    Venezuela  6.810  6.084  5.250  4.806  4.707      -2.103
# 126       Zambia  5.129  4.795  4.514  4.377  4.107      -1.022
# 132     Zimbabwe  4.610  4.193  3.875  3.692  3.663      -0.947
# 133        Haiti  4.518  4.028  3.603  3.582  3.597      -0.921
# 136       Malawi  4.292  4.156  3.970  3.587  3.410      -0.882
# 134     Botswana  4.332  3.974  3.766  3.590  3.488      -0.844
# 137        Yemen  4.077  3.724  3.593  3.355  3.380      -0.697
# 30        Brazil  6.983  6.952  6.635  6.419  6.300      -0.683
# 129      Liberia  4.571  3.622  3.533  3.495  3.975      -0.596
# 22        Mexico  7.187  6.778  6.578  6.488  6.595      -0.592
# 128        India  4.565  4.404  4.315  4.190  4.015      -0.550
# 139     Tanzania  3.781  3.666  3.349  3.303  3.231      -0.550
# 32     Singapore  6.798  6.739  6.572  6.343  6.262      -0.536
# 76       Belarus  5.813  5.802  5.569  5.483  5.323      -0.490
# ...

# %%
unified = unified.sort_values(by = ['difference'], ascending = [False])

# %%
unified.tail(10)
# Out:
#        country   2015   2016   2017   2018   2019  difference
# 22      Mexico  7.187  6.778  6.578  6.488  6.595      -0.592
# 129    Liberia  4.571  3.622  3.533  3.495  3.975      -0.596
# 30      Brazil  6.983  6.952  6.635  6.419  6.300      -0.683
# 137      Yemen  4.077  3.724  3.593  3.355  3.380      -0.697
# 134   Botswana  4.332  3.974  3.766  3.590  3.488      -0.844
# 136     Malawi  4.292  4.156  3.970  3.587  3.410      -0.882
# 133      Haiti  4.518  4.028  3.603  3.582  3.597      -0.921
# 132   Zimbabwe  4.610  4.193  3.875  3.692  3.663      -0.947
# 126     Zambia  5.129  4.795  4.514  4.377  4.107      -1.022
# 101  Venezuela  6.810  6.084  5.250  4.806  4.707      -2.103

# %%
sns.barplot(y = unified["country"][-20:], x = unified["difference"][-20:])
plt.title('2015-2019 mutluluk skoru en çok düşen 20 ülke')
plt.show()

# %%
unified.head(10)
# Out:
#           country   2015   2016   2017   2018   2019  difference
# 96          Benin  3.340  3.484  3.657  4.141  4.883       1.543
# 93    Ivory Coast  3.655  3.916  4.180  4.671  4.944       1.289
# 127          Togo  2.839  3.303  3.495  3.999  4.085       1.246
# 56       Honduras  4.788  4.871  5.181  5.504  5.860       1.072
# 106  Burkina Faso  3.587  3.739  4.032  4.424  4.587       1.000
# 59        Hungary  4.800  5.145  5.324  5.620  5.758       0.958
# 45        Romania  5.124  5.528  5.825  5.945  6.070       0.946
# 98          Gabon  3.896  4.121  4.465  4.758  4.799       0.903
# 102      Cambodia  3.819  3.907  4.168  4.433  4.700       0.881
# 109        Guinea  3.656  3.607  3.507  3.964  4.534       0.878

# %%
sns.barplot(y = unified["country"][:20], x = unified["difference"][:20])
plt.title('2015-2019 mutluluk skoru en çok artan 20 ülke')
plt.show()

# %% [markdown]
# https://app.patika.dev/ozanbektas ..
